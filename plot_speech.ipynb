# %%
from matplotlib import pyplot as plt
import torchaudio
plt.axis('off')
plt.plot(torchaudio.load('./jsut_resampled/BASIC5000_0001.wav')[0].t().numpy())

# %%
plt.axis('off')
plt.plot(torchaudio.load('./jsut_resampled/BASIC5000_0001.wav')[0].t().numpy())
